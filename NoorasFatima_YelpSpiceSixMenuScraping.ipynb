# %%
# Nooras Fatima 
# https://github.com/nooras

from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as bs4
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import Chrome
import pandas as pd
import re
import requests
import urllib.parse

# %% [markdown]
# ### Step 1 : Searching
# - Part a : By Seleinium
# - Part b : By Beautifulsoup By entering direct link
#
# ### Step 2 : Finding Spice Six restaurant name (Beautifulsoup)
# ### Step 4 : Finding link of menu page of Spice Six (Beautifulsoup)
# ### Step 5 : Go to that link and retrieving data (Menu Name , Menu Price) of Spice Six Restaurant(Beautifulsoup)
# ### Step 6 : Saving data in excel file(Beautifulsoup)

# %% [markdown]
# # Solution

# %% [markdown]
# ### Step 1 : Searching

# %% [markdown]
# - Part a : By Seleinium

# %%
#Use Incognito mode when scraping
chrome_options = Options()
chrome_options.add_argument(" — incognito")
browser = webdriver.Chrome(options=chrome_options)

# %%
browser.get("https://www.yelp.com/")

# %%
text_input1 = browser.find_element_by_id("find_desc")

text_input1.send_keys("Indian food")

# %%
text_input1 = browser.find_element_by_id("dropperText_Mast")

text_input1.send_keys("Redando Beach, CA")

# %%
# Now we can grab the search button and click it
search_button = browser.find_element_by_id("header-search-submit")
search_button.click()

# %%
browser.page_source
# Out:
# '<html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;" class=""><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="Content-Language" content="en-US"><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/97ea654d5227/assets/img/logos/yelp_burst.svg" content="#c41200"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/118ff475a341/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script async="" src="https://www.google-analytics.com/analytic
# ...

# %% [markdown]
# ### Combining Selenium and BeautifulSoup

# %%
# We can feed that into Beautiful Soup
soup = BeautifulSoup(browser.page_source, "html.parser")

# %% [markdown]
# ### Step 1 : Searching
#
# - Part b : By Beautifulsoup By entering direct link

# %%
find = "Indian Food"
near = "Redando Beach, CA"

url = "https://www.yelp.com/search?find_desc=" + find + "&find_loc=" + near

response = requests.get(url)

#print(response)

data = response.text

#print(data)

soup = BeautifulSoup(data,'html.parser')

# %% [markdown]
# ### Step 2 : Finding Spice Six restaurant name By Beautifulsoup

# %%
spice_six = soup.find('a', text = re.compile('Spice Six'))

# %% [markdown]
# ### Step 3 : Retrieving link

# %%
spice_six['href']
# Out:
# '/biz/spice-six-hermosa-beach-2?osq=Indian+Food'

# %%
url = "https://www.yelp.com" + spice_six['href']

response = requests.get(url)

#print(response)

data = response.text

#print(data)

soup = BeautifulSoup(data,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script nonce="573dc628">
#             (function() {
#                 var main = null;
#
# ...

# %% [markdown]
# ### Step 4 : Converting link of menu page of Spice Six

# %%
# Direct link fetching 
url
# Out:
# 'https://www.yelp.com/biz/spice-six-hermosa-beach-2?osq=Indian+Food'

# %%
url = url.split("?")[0]
url = url.replace("biz", "menu")
url
# Out:
# 'https://www.yelp.com/menu/spice-six-hermosa-beach-2'

# %% [markdown]
# ### Step 5 : Go to that link and retrieving data (Menu Name , Menu Price)

# %%
response = requests.get(url)

#print(response)

data = response.text

#print(data)

soup = BeautifulSoup(data,'html.parser')

# %%
soup.prettify()
# Out:
# '<!DOCTYPE HTML>\n<!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!-->\n<html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml">\n <!--<![endif]-->\n <head>\n  <script nonce="31bcc0c4">\n   (function() {\n                var main = null;\n\n                var main=function(){window.onerror=function(k,a,c,i,f){var j=(document.getElementsByTagName("html")[0].getAttribute("webdriver")==="true"||navigator.userAgent==="selenium");var h=f&&(f.name==="ServerSideRenderingError"||f.name==="CSRFallbackError");i
# ...

# %%
# menu_name = []
# menu_price = []

# for j in soup.find_all('div', {"class":"menu-item"}):
#     menu_item_name = j.find('h4')
#     m = menu_item_name.text.strip()
#     menu_name.append(m)
#     menu_item_price = j.find('div',{"class":"menu-item-prices"})
#     p = menu_item_price.text.strip()
#     menu_price.append(p)

#section-header
#menu-item
category_list = []
for j in soup.find_all('div', {"class":"section-header"}):
    category = j.find('h2')
    c = category.text.strip()
    category_list.append(c)
#print(category_list)
menu = {}   
count = 0
for j in soup.find_all('div', {"class":"u-space-b3"}): 
    menu_name = []
    menu_price = []
    for i in j.find_all('div', {"class":"menu-item"}):
        menu_item_name = i.find('h4')
        m = menu_item_name.text.strip()
        menu_name.append(m)
        menu_item_price = i.find('div',{"class":"menu-item-prices"})
        p = menu_item_price.text.strip()
        menu_price.append(p)
    data={'Menu Name': menu_name, 'Menu Prices': menu_price}
    df=pd.DataFrame(data=data)
    menu[category_list[count]] = df.to_dict("records")
    count += 1
    if count == len(category_list):
        break
menu
# Out:
# {'Monthly Specials': [{'Menu Name': '2 Tandoori Chicken Special',
#    'Menu Prices': '$16.99'},
#   {'Menu Name': 'Tandoori Chicken', 'Menu Prices': '$10.99'},
#   {'Menu Name': 'Chicken Tikka Tacos', 'Menu Prices': '$8.99'},
#   {'Menu Name': 'Saffron Kheer', 'Menu Prices': '$3.99'}],
#  'Lunch and Dinner Combo': [{'Menu Name': 'Classic Combo',
#    'Menu Prices': '$7.99'},
#   {'Menu Name': 'Famous Combo', 'Menu Prices': '$8.99'},
#   {'Menu Name': 'Premium Combo', 'Menu Prices': '$11.99'}],
#  'Beverages': [{'Menu Name': 'Mango Lassi', 'Menu Prices': '$3.99'},
#   {'Menu Name': 'Sweet Lassi', 'Menu Prices': '$3.99'},
#   {'Menu Name': 'Salted Lassi', 'Menu Prices': '$3.99'}],
#  'Appetizers': [{'Menu Name': '2 Pieces Samosa', 'Menu Prices': '$2.99'},
#   {'Menu Name': 'Onion Bhajiya', 'Menu Prices': '$6.99'},
#   {'Menu Name': 'Samosa Chat', 'Menu Prices': '$5.99'},
#   {'Menu Name': 'Papdi Chat', 'Menu Prices': '$5.99'},
# ...

# %%
menu_name
# Out:
# ['Chicken Kids Meal', 'Potato Kids Meal']

# %%
menu_price
# Out:
# ['$6.99', '$6.99']

# %%
{"Restaurant Name": "Spice Six", "Restaurant Menu": menu}
# Out:
# {'Restaurant Name': 'Spice Six',
#  'Restaurant Menu': {'Monthly Specials': [{'Menu Name': '2 Tandoori Chicken Special',
#     'Menu Prices': '$16.99'},
#    {'Menu Name': 'Tandoori Chicken', 'Menu Prices': '$10.99'},
#    {'Menu Name': 'Chicken Tikka Tacos', 'Menu Prices': '$8.99'},
#    {'Menu Name': 'Saffron Kheer', 'Menu Prices': '$3.99'}],
#   'Lunch and Dinner Combo': [{'Menu Name': 'Classic Combo',
#     'Menu Prices': '$7.99'},
#    {'Menu Name': 'Famous Combo', 'Menu Prices': '$8.99'},
#    {'Menu Name': 'Premium Combo', 'Menu Prices': '$11.99'}],
#   'Beverages': [{'Menu Name': 'Mango Lassi', 'Menu Prices': '$3.99'},
#    {'Menu Name': 'Sweet Lassi', 'Menu Prices': '$3.99'},
#    {'Menu Name': 'Salted Lassi', 'Menu Prices': '$3.99'}],
#   'Appetizers': [{'Menu Name': '2 Pieces Samosa', 'Menu Prices': '$2.99'},
#    {'Menu Name': 'Onion Bhajiya', 'Menu Prices': '$6.99'},
#    {'Menu Name': 'Samosa Chat', 'Menu Prices': '$5.99'},
# ...

# %%
### Step 6 : Saving data in excel file
# data={'Menu Name': menu_name, 'Menu Prices': menu_price}
# df=pd.DataFrame(data=data)
# df.index+=1
# df.to_excel("yelp.xlsx")

# %%
#df

# %%
#!pip install pymongo #Installing Pymongo

# %% [markdown]
# ## Inserting data into Monodb

# %%
import pymongo
from bson.objectid import ObjectId

# %%
client = pymongo.MongoClient('mongodb+srv://sumi:'+urllib.parse.quote_plus('sumi@123')+'@codemarket-staging.k16z7.mongodb.net/codemarket_shiraz?retryWrites=true&w=majority')

# %%
db = client.codemarket_shiraz
db
# Out:
# Database(MongoClient(host=['codemarket-staging-shard-00-02.k16z7.mongodb.net:27017', 'codemarket-staging-shard-00-01.k16z7.mongodb.net:27017', 'codemarket-staging-shard-00-00.k16z7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-kk26oz-shard-0', ssl=True), 'codemarket_shiraz')

# %%
db.list_collection_names()
# Out:
# ['Yelp', 'menu_data', 'menu', 'restaurantMenu']

# %%
restaurant = db.restaurantMenu

# %%
restaurant.count_documents({})
# Out:
# 87

# %%
#df.to_dict("records") #Converting dataframe into dictionary

# %%
restaurant.insert_many([{"Restaurant Name": "Spice Six", "Restaurant Menu": menu}])

# %%
restaurant.count_documents({})
# Out:
# 89

# %%
list(restaurant.find({}))
# Out:
# [{'_id': ObjectId('5fdc53c6f908dd369efd5b6c'),
#   'Menu Name': '2 Tandoori Chicken Special',
#   'Menu Prices': '$16.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b6d'),
#   'Menu Name': 'Tandoori Chicken',
#   'Menu Prices': '$10.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b6e'),
#   'Menu Name': 'Chicken Tikka Tacos',
#   'Menu Prices': '$8.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b6f'),
#   'Menu Name': 'Saffron Kheer',
#   'Menu Prices': '$3.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b70'),
#   'Menu Name': 'Classic Combo',
#   'Menu Prices': '$7.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b71'),
#   'Menu Name': 'Famous Combo',
#   'Menu Prices': '$8.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b72'),
#   'Menu Name': 'Premium Combo',
#   'Menu Prices': '$11.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b73'),
#   'Menu Name': 'Mango Lassi',
#   'Menu Prices': '$3.99'},
#  {'_id': ObjectId('5fdc53c6f908dd369efd5b74'),
#   'Menu Name': 'Sweet Lassi',
# ...

# %%
db.list_collection_names()
# Out:
# ['Yelp', 'menu_data', 'menu', 'restaurantMenu']

# %%
r = restaurant.find({"Restaurant Name": "Spice Six"})

# %%
for x in r:
    print(x)
# Out:
# {'_id': ObjectId('5fdcbf8e2a0e3da4cae41a6f'), 'Restaurant Name': 'Spice Six', 'Restaurant Menu': {'Monthly Specials': [{'Menu Name': '2 Tandoori Chicken Special', 'Menu Prices': '$16.99'}, {'Menu Name': 'Tandoori Chicken', 'Menu Prices': '$10.99'}, {'Menu Name': 'Chicken Tikka Tacos', 'Menu Prices': '$8.99'}, {'Menu Name': 'Saffron Kheer', 'Menu Prices': '$3.99'}], 'Lunch and Dinner Combo': [{'Menu Name': 'Classic Combo', 'Menu Prices': '$7.99'}, {'Menu Name': 'Famous Combo', 'Menu Prices': '$8.99'}, {'Menu Name': 'Premium Combo', 'Menu Prices': '$11.99'}], 'Beverages': [{'Menu Name': 'Mango Lassi', 'Menu Prices': '$3.99'}, {'Menu Name': 'Sweet Lassi', 'Menu Prices': '$3.99'}, {'Menu Name': 'Salted Lassi', 'Menu Prices': '$3.99'}], 'Appetizers': [{'Menu Name': '2 Pieces Samosa', 'Menu Prices': '$2.99'}, {'Menu Name': 'Onion Bhajiya', 'Menu Prices': '$6.99'}, {'Menu Name': 'Samosa Chat', 'Menu Prices': '$5.99'}, {'Menu Name': 'Papdi Chat', 'Menu Prices': '$5.99'}, {'Menu Name': 'Chana
# ...
